# %%
#import dependencies and setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# %%
#load files
food_supply_to_load = "../COVID_Diet_Data/Food_Supply_Quantity_kg_Data.csv"

#read file and store as dataframe
food_supply = pd.read_csv(food_supply_to_load)
pd
food_supply
# Out:
#                                 Country  Alcoholic Beverages  Animal fats  \
# 0                           Afghanistan               0.0014       0.1973
# 1                               Albania               1.6719       0.1357
# 2                               Algeria               0.2711       0.0282
# 3                                Angola               5.8087       0.0560
# 4                   Antigua and Barbuda               3.5764       0.0087
# ..                                  ...                  ...          ...
# 165  Venezuela (Bolivarian Republic of)               2.5952       0.0403
# 166                             Vietnam               1.4591       0.1640
# 167                               Yemen               0.0364       0.0446
# 168                              Zambia               5.7360       0.0829
# 169                            Zimbabwe               4.0552       0.0755
#
#      Animal Products  Aquatic Products, Other  Cereals - Excluding Beer  \
# ...

# %%
country_count = len(food_supply["Country"].unique())
country_count
# Out:
# 170

# %%
food_supply.head()
# Out:
#                Country  Alcoholic Beverages  Animal fats  Animal Products  \
# 0          Afghanistan               0.0014       0.1973           9.4341
# 1              Albania               1.6719       0.1357          18.7684
# 2              Algeria               0.2711       0.0282           9.6334
# 3               Angola               5.8087       0.0560           4.9278
# 4  Antigua and Barbuda               3.5764       0.0087          16.6613
#
#    Aquatic Products, Other  Cereals - Excluding Beer    Eggs  Fish, Seafood  \
# 0                      0.0                   24.8097  0.2099         0.0350
# 1                      0.0                    5.7817  0.5815         0.2126
# 2                      0.0                   13.6816  0.5277         0.2416
# 3                      0.0                    9.1085  0.0587         1.7707
# 4                      0.0                    5.9960  0.2274         4.1489
#
# ...

# %%
#Top 10 countries with the most deaths
most_deaths = food_supply.sort_values("Deaths", ascending=False)
most_deaths
# Out:
#             Country  Alcoholic Beverages  Animal fats  Animal Products  \
# 14          Belgium               5.3730       0.8559          17.7279
# 138        Slovenia               4.9933       1.1248          18.9196
# 159  United Kingdom               5.2632       0.2754          18.8798
# 38          Czechia               9.8498       0.8945          17.8065
# 74            Italy               3.1892       0.2834          19.0329
# ..              ...                  ...          ...              ...
# 80         Kiribati               0.2970       0.0486           8.8958
# 81     Korea, North               0.8981       0.0010           3.3933
# 105         Myanmar               0.2195       0.1751          13.5188
# 109   New Caledonia               5.0363       0.0821          11.7818
# 155    Turkmenistan               0.5038       0.3373          16.0611
#
#      Aquatic Products, Other  Cereals - Excluding Beer    Eggs  Fish, Seafood  \
# ...

# %%
top_ten_deaths = most_deaths.head(10)
top_ten_deaths
# Out:
#                       Country  Alcoholic Beverages  Animal fats  \
# 14                    Belgium               5.3730       0.8559
# 138                  Slovenia               4.9933       1.1248
# 159            United Kingdom               5.2632       0.2754
# 38                    Czechia               9.8498       0.8945
# 74                      Italy               3.1892       0.2834
# 18     Bosnia and Herzegovina               4.7876       0.0585
# 114           North Macedonia               1.9045       0.3784
# 161  United States of America               4.8647       0.1681
# 123                  Portugal               4.7147       0.4077
# 21                   Bulgaria               7.0834       0.2488
#
#      Animal Products  Aquatic Products, Other  Cereals - Excluding Beer  \
# 14           17.7279                   0.0010                    6.6704
# 138          18.9196                   0.0005                    7.6345
# ...

# %%
least_deaths = food_supply.sort_values("Deaths", ascending=True)
least_deaths
# Out:
#                               Country  Alcoholic Beverages  Animal fats  \
# 85   Lao People's Democratic Republic               0.7883       0.0979
# 139                   Solomon Islands               0.8298       0.1038
# 150                       Timor-Leste               0.4459       0.0897
# 24                           Cambodia               4.5783       0.0377
# 128             Saint Kitts and Nevis               4.0867       0.1735
# ..                                ...                  ...          ...
# 80                           Kiribati               0.2970       0.0486
# 81                       Korea, North               0.8981       0.0010
# 105                           Myanmar               0.2195       0.1751
# 109                     New Caledonia               5.0363       0.0821
# 155                      Turkmenistan               0.5038       0.3373
#
#      Animal Products  Aquatic Products, Other  Cereals - Excluding Beer  \
# ...

# %%
bottom_10_deaths = least_deaths.head(10)
bottom_10_deaths
# Out:
#                               Country  Alcoholic Beverages  Animal fats  \
# 85   Lao People's Democratic Republic               0.7883       0.0979
# 139                   Solomon Islands               0.8298       0.1038
# 150                       Timor-Leste               0.4459       0.0897
# 24                           Cambodia               4.5783       0.0377
# 128             Saint Kitts and Nevis               4.0867       0.1735
# 164                           Vanuatu               0.2424       0.0793
# 131                             Samoa               1.4236       0.2262
# 41                           Dominica               0.9410       0.0319
# 160       United Republic of Tanzania               4.5185       0.0403
# 166                           Vietnam               1.4591       0.1640
#
#      Animal Products  Aquatic Products, Other  Cereals - Excluding Beer  \
# 85            3.6579                   0.0006                   16.3943
# ...
